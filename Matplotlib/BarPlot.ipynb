# %%
#Bivariate Analysis
#Numerical vs Categorical
#Aggregate analysis of groups

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
child = ['5','20','40','30','10']
colors = ['red','blue','green','yellow','pink']
plt.bar(colors, child)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(colors, child)
# Out:
# <BarContainer object of 5 artists>

# %%
df = pd.read_csv("batsman_season_record.csv")
df
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.bar(np.arange(df.shape[0]) - 0.2,df['2015'], width = 0.2)
plt.bar(np.arange(df.shape[0]),df['2016'], width = 0.2)
plt.bar(np.arange(df.shape[0]) + 0.2,df['2017'], width = 0.2)

plt.xticks(np.arange(df.shape[0]), df['batsman'])
# Out:
# ([<matplotlib.axis.XTick at 0x1b1e83a2d80>,
#   <matplotlib.axis.XTick at 0x1b1e8990b90>,
#   <matplotlib.axis.XTick at 0x1b1e7073560>,
#   <matplotlib.axis.XTick at 0x1b1e8997e30>,
#   <matplotlib.axis.XTick at 0x1b1e898caa0>],
#  [Text(0, 0, 'AB de Villiers'),
#   Text(1, 0, 'DA Warner'),
#   Text(2, 0, 'MS Dhoni'),
#   Text(3, 0, 'RG Sharma'),
#   Text(4, 0, 'V Kohli')])
